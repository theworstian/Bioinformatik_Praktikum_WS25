# %% [markdown]
# **2025W 301599-1 Praktikum Bioinformatik**
# Julianne Weiß
# Sarah Strolz
# Sebastian Rossböck
# # Comparison of Sequence-Based and Structure-Based RNA Alignments
# Sequence-based and structure-aware alignment strategies are compared, and the effect of manual inspection and structure-guided correction on alignment
# quality is evaluated.

# %%
import sys
import os
#Helper functions for reading FASTA / STOCKHOLM and CLUSTAL
#and for calculating Sum of Pairs Score
def read_fasta_alignment(filename):
    sequences = {}
    current_id = None
    
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                current_id = line[1:].split()[0]
                sequences[current_id] = ""
            elif current_id is not None:
                sequences[current_id] += line
    
    return sequences


def read_clustal_alignment(filename):
    sequences = {}
    
    with open(filename, "r") as f:
        for line in f:
            line = line.rstrip()
            # Skip header, empty lines, and conservation lines
            if not line or line.startswith("CLUSTAL") or line.startswith(" ") or "*" in line or ":" in line:
                continue
            
            parts = line.split()
            if len(parts) >= 2:
                seq_id = parts[0]
                seq_chunk = parts[1]
                
                if seq_id not in sequences:
                    sequences[seq_id] = ""
                sequences[seq_id] += seq_chunk
    
    return sequences


def read_stockholm_alignment(filename):
    sequences = {}
    
    with open(filename, "r") as f:
        for line in f:
            line = line.rstrip()
            # Skip header lines and annotation lines
            if line.startswith("#") or line.startswith("//") or not line:
                continue
            
            parts = line.split()
            if len(parts) >= 2:
                seq_id = parts[0]
                seq = parts[1]
                
                if seq_id not in sequences:
                    sequences[seq_id] = ""
                sequences[seq_id] += seq
    
    return sequences


def calculate_sps(reference_aln, test_aln):
    """
    Calculate Sum-of-Pairs Score (SPS)
    
    SPS = (number of correctly aligned residue pairs) / (total pairs in reference)
    """
    # Find common sequence IDs
    common_ids = set(reference_aln.keys()) & set(test_aln.keys())
    
    if len(common_ids) < 2:
        print(f"Warning: Only {len(common_ids)} common sequences found")
        return 0.0
    
    common_ids = sorted(common_ids)
    
    # Check alignment lengths
    ref_len = len(next(iter(reference_aln.values())))
    test_len = len(next(iter(test_aln.values())))
    
    print(f"Reference alignment length: {ref_len}")
    print(f"Test alignment length: {test_len}")
    print(f"Common sequences: {len(common_ids)}")
    
    # Count correctly aligned pairs
    total_pairs = 0
    correct_pairs = 0
    
    # For each column position in reference
    for ref_col in range(ref_len):
        # For each pair of sequences
        for i in range(len(common_ids)):
            for j in range(i + 1, len(common_ids)):
                seq1_id = common_ids[i]
                seq2_id = common_ids[j]
                
                # Get residues at this column in reference
                ref_res1 = reference_aln[seq1_id][ref_col]
                ref_res2 = reference_aln[seq2_id][ref_col]
                
                # Skip if either is a gap in reference
                if ref_res1 == '-' or ref_res2 == '-':
                    continue
                
                total_pairs += 1
                
                # Find these residues in test alignment
                # We need to find the corresponding non-gap positions
                test_pos1 = find_residue_position(test_aln[seq1_id], reference_aln[seq1_id], ref_col)
                test_pos2 = find_residue_position(test_aln[seq2_id], reference_aln[seq2_id], ref_col)
                
                # Check if they're aligned in test (same column position)
                if test_pos1 is not None and test_pos2 is not None and test_pos1 == test_pos2:
                    correct_pairs += 1
    
    if total_pairs == 0:
        return 0.0
    
    sps = correct_pairs / total_pairs
    print(f"Correct pairs: {correct_pairs}")
    print(f"Total pairs: {total_pairs}")
    
    return sps


def find_residue_position(test_seq, ref_seq, ref_col):
    """
    Find where the residue at ref_col in ref_seq appears in test_seq
    Returns the column position in test_seq, or None if not found
    """
    # Count non-gap characters up to ref_col in reference
    ref_residue_count = 0
    for i in range(ref_col + 1):
        if ref_seq[i] != '-':
            ref_residue_count += 1
    
    # Find the same residue number in test sequence
    test_residue_count = 0
    for test_col in range(len(test_seq)):
        if test_seq[test_col] != '-':
            test_residue_count += 1
            if test_residue_count == ref_residue_count:
                return test_col
    
    return None

def get_sci(filename):
    """Extract Structure Conservation Index from RNAalifold output"""
    with open(filename, "r") as f:
        for line in f:
            if "[sci =" in line:
                # Format: (...) [sci = 0.8020]
                sci_str = line.split("[sci =")[1].split("]")[0].strip()
                return float(sci_str)
    return None

# Extract bit scores from cmsearch output
def extract_bit_scores(filename):
    """Extract bit scores from cmsearch output"""
    bit_scores = []
    
    with open(filename, "r") as f:
        for line in f:
            line_stripped = line.strip()
            
            # Look for lines that start with (number) followed by ! or ?
            if line_stripped.startswith("("):
                parts = line_stripped.split()
                # Format: (rank) ! E-value score ...
                if len(parts) >= 4 and (parts[1] == "!" or parts[1] == "?"):
                    try:
                        # Fourth element is the bit score
                        bit_score = float(parts[3])
                        bit_scores.append(bit_score)
                    except:
                        pass
    
    return bit_scores

# %%
#Download seed alignment and all sequences for family
print("-------------------------------------")
print("------------Download Data------------")
print("-------------------------------------")
# Download seed alignment in fasta
# !wget https://rfam.org/family/RF00254/alignment/fasta -O RF00254_seed.fa
# Download seed alignment without gap (ungapped) (these will be needed by clustalw and locarna)
# !wget https://rfam.org/family/RF00254/alignment/fastau -O RF00254_seed_ungapped.fa
# Download and extract all sequences
# !wget https://ftp.ebi.ac.uk/pub/databases/Rfam/15.1/fasta_files/RF00254.fa.gz
# !wsl gunzip RF00254.fa.gz

print("cell done")
# Out:
# -------------------------------------
# ------------Download Data------------
# -------------------------------------
# --2026-02-12 17:56:01--  https://rfam.org/family/RF00254/alignment/fasta
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1825 (1,8K) [text/plain]
# Saving to: 'RF00254_seed.fa'
#
#      0K .                                                     100%  669M=0s
#
# 2026-02-12 17:56:02 (669 MB/s) - 'RF00254_seed.fa' saved [1825/1825]
#
# --2026-02-12 17:56:02--  https://rfam.org/family/RF00254/alignment/fastau
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1507 (1,5K) [text/plain]
# Saving to: 'RF00254_seed_ungapped.fa'
#
#      0K .                                                     100%  575M=0s
#
# 2026-02-12 17:56:03 (575 MB/s) - 'RF00254_seed_ungapped.fa' saved [1507/1507]
#
# --2026-02-12 17:56:03--  https://ftp.ebi.ac.uk/pub/databases/Rfam/15.1/fasta_files/RF00254.fa.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 217139 (212K) [application/x-gzip]
# Saving to: 'RF00254.fa.gz'
#
#      0K .......... .......... .......... .......... .......... 23% 1,19M 0s
#     50K .......... .......... .......... .......... .......... 47% 1,04M 0s
#    100K .......... .......... .......... .......... .......... 70% 8,29M 0s
#    150K .......... .......... .......... .......... .......... 94%  842K 0s
#    200K .......... ..                                         100% 37,7M=0,2s
#
# 2026-02-12 17:56:04 (1,35 MB/s) - 'RF00254.fa.gz' saved [217139/217139]
# cell done

# %%
#create the full alignment
# Download the Rfam covariance model
# !wsl wget https://rfam.org/family/RF00254/cm -O RF00254_rfam.cm
# Align all sequences to the covariance model to create the full alignment
# !wsl cmalign RF00254_rfam.cm RF00254.fa > RF00254_full_alignment.sto

print("cell done")
# Out:
# --2026-02-12 17:57:47--  https://rfam.org/family/RF00254/cm
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54932 (54K) [text/plain]
# Saving to: â€˜RF00254_rfam.cmâ€™
#
#      0K .......... .......... .......... .......... .......... 93%  687K 0s
#     50K ...                                                   100% 6.79T=0.07s
#
# 2026-02-12 17:57:47 (737 KB/s) - â€˜RF00254_rfam.cmâ€™ saved [54932/54932]
# cell done

# %%
#Create Sequence-based alignments are produced with Clustal W
#Followed by consensus structure prediction using RNAalifold
print("---------------------------------------------------")
print("----------Create Sequence Based Alignment----------")
print("---------------------------------------------------")
#Read the Sequences from the ungapped seed file and save it to a file, to prepare it as input for clustalw
sequences = {}
current_id = None

#read sequenceId / sequence from file
with open("RF00254_seed_ungapped.fa","r") as f:
    for line in f:
        #print(line)
        if line.startswith(">"):
            current_id = line[1:].split()[0]
            sequences[current_id] = ""
        elif current_id is not None:
            sequences[current_id] += line

#print it to make sure we have data (we expect 4-20 sequences)
for seq_id, seq in sequences.items():
    print(f"{seq_id}: {len(seq)} nt")

#write sequences to file
with open("RF00254_for_clustalw.fa", "w") as f:
    for seq_id, seq in sequences.items():
        f.write(f">{seq_id}\n{seq}\n")
        
#Run clustalw
# !wsl clustalw -infile=RF00254_for_clustalw.fa -outfile=RF00254_clustalw.aln -output=CLUSTAL

#Use the clustalw alignment as input for RNAalifold to predict consensus structure
# --sci flag for structure conservation index
# !wsl RNAalifold --mis --cfactor=0.6 --nfactor=0.5 --sci RF00254_clustalw.aln > RF00254_clustalw_alifold.out

#show RNAalifold output
print("-------------------------------------")
print("----------RNAalifold output----------")
print("-------------------------------------")
with open("RF00254_clustalw_alifold.out","r") as f:
    for line in f:
        print(line)

print("cell done")
# Out:
# ---------------------------------------------------
# ----------Create Sequence Based Alignment----------
# ---------------------------------------------------
# AL669869.10/100495-100571: 79 nt
# AY865955.1/411-487: 79 nt
# AL606727.3/61372-61292: 83 nt
# CR478286.10/109802-109722: 83 nt
# AC154660.2/77731-77651: 83 nt
# AY866308.1/534-614: 83 nt
# AF480551.1/1-81: 83 nt
# AY865836.1/531-611: 83 nt
# AY865833.1/553-633: 83 nt
# AY865835.1/569-649: 83 nt
# AF480552.1/1-81: 83 nt
# AC119847.12/19552-19632: 83 nt
# URS0001A16A8F_9606/6-102: 99 nt
# URS0001A16A6B_9606/1-105: 107 nt
#
#
#
#  CLUSTAL 2.1 Multiple Sequence Alignments
# Sequences (6:7) Aligned. Score:  98
# Sequences (6:8) Aligned. Score:  62
# Sequences (6:9) Aligned. Score:  62
# Sequences (6:10) Aligned. Score:  65
# Sequences (6:11) Aligned. Score:  64
# Sequences (6:12) Aligned. Score:  62
# Sequences (6:13) Aligned. Score:  79
# Sequences (6:14) Aligned. Score:  64
# Sequences (7:8) Aligned. Score:  64
# Sequences (7:9) Aligned. Score:  64
# Sequences (7:10) Aligned. Score:  66
# Sequences (7:11) Aligned. Score:  65
# Sequences (7:12) Aligned. Score:  64
# Sequences (7:13) Aligned. Score:  79
# Sequences (7:14) Aligned. Score:  65
# Sequences (8:9) Aligned. Score:  96
# Sequences (8:10) Aligned. Score:  96
# Sequences (8:11) Aligned. Score:  97
# Sequences (8:12) Aligned. Score:  95
# Sequences (8:13) Aligned. Score:  59
# Sequences (8:14) Aligned. Score:  97
# Sequences (9:10) Aligned. Score:  97
# Sequences (9:11) Aligned. Score:  98
# Sequences (9:12) Aligned. Score:  96
# Sequences (9:13) Aligned. Score:  58
# Sequences (9:14) Aligned. Score:  98
# Sequences (10:11) Aligned. Score:  98
# Sequences (10:12) Aligned. Score:  96
# Sequences (10:13) Aligned. Score:  25
# Sequences (10:14) Aligned. Score:  98
# Sequences (11:12) Aligned. Score:  97
# Sequences (11:13) Aligned. Score:  58
# Sequences (11:14) Aligned. Score:  100
# Sequences (12:13) Aligned. Score:  25
# Sequences (12:14) Aligned. Score:  97
# Sequences (13:14) Aligned. Score:  48
# Guide tree file created:   [RF00254_for_clustalw.dnd]
#
# There are 13 groups
# Start of Multiple Alignment
#
# Aligning...
# Group 1: Sequences:   2      Score:1520
# Group 2: Sequences:   3      Score:1528
# Group 3: Sequences:   4      Score:1502
# Group 4: Sequences:   5      Score:1514
# Group 5: Sequences:   6      Score:1506
# Group 6: Sequences:   7      Score:1147
# Group 7: Sequences:   2      Score:1396
# Group 8: Sequences:   2      Score:1529
# Group 9: Sequences:   3      Score:1495
# Group 10: Sequences:   4      Score:1176
# Group 11: Sequences:   5      Score:1121
# Group 12: Sequences:   7      Score:984
# Group 13: Sequences:  14      Score:999
# Alignment Score 24495
#
# CLUSTAL-Alignment file created  [RF00254_clustalw.aln]
#
# -------------------------------------
# ----------RNAalifold output----------
# -------------------------------------
# -----------GYYSBRCYYUAGCAGCACGUAAAUAUUGGCGUaKWRRAAUMURKAUUAAMCWCCARUAUURMcUGUGCUGCUKHAGURWGRY-------------
#
# ..........((((.((((..(((((((((..((((((((.......................))))))))...)))))))))..)))).))))............ (-27.51 = -26.55 +  -0.96) [sci = 0.8195]
#
# cell done
# 14 sequences; length of alignment 106.

# %%
#what are we doing here?
print("----------------------------------------------------")
print("----------Create Structure Based Alignment----------")
print("----------------------------------------------------")

#we use locarna to create the structure based alignment
# --consensus-structture alifold means, that it used RNAalifold internally for the consensus structure. This way we can compare it better with the clustalw/RNAalifold approach
# --stockholm means that the output is in the stockholm format, which we will need for infernal
# !wsl mlocarna --stockholm --consensus-structure alifold RF00254_seed_ungapped.fa

print("cell done")
# Out:
# ----------------------------------------------------
# Results written to target directory /mnt/c/Users/seppo/Desktop/ws25_bioinf/rf12345/RF00254_seed_ungapped.out.
# cell done

# %%
#Now we can compare the two
#We load the reference alignment and create the SPS of the clustalw alignment and the locarna alignment with it.
#to see how well the alignments compare to the reference alignment from rfam

# Load reference alignment (Rfam seed)
print("Loading reference alignment...")
reference = read_fasta_alignment("RF00254_seed.fa")

# Load Clustal W alignment
print("\n--- Clustal W Alignment ---")
clustalw = read_clustal_alignment("RF00254_clustalw.aln")
sps_clustalw = calculate_sps(reference, clustalw)
print(f"SPS for Clustal W: {sps_clustalw:.4f}")

# Load LocARNA alignment
print("\n--- LocARNA Alignment ---")
locarna = read_stockholm_alignment("RF00254_seed_ungapped.out/results/result.stk")
sps_locarna = calculate_sps(reference, locarna)
print(f"SPS for LocARNA: {sps_locarna:.4f}")

# Load SCI values
sci_clustalw = get_sci("RF00254_clustalw_alifold.out")

#We need to run RNAalifold on the locarna alignment to get the SCI (can we do this better?)
# !wsl RNAalifold --mis --cfactor=0.6 --nfactor=0.5 --sci RF00254_seed_ungapped.out/results/result.stk > RF00254_locarna_alifold.out

sci_locarna = get_sci("RF00254_locarna_alifold.out")

# Summary
print("RESULTS")
print(f"Clustal W: SPS = {sps_clustalw:.4f}, SCI = {sci_clustalw:.4f}")
print(f"LocARNA:   SPS = {sps_locarna:.4f}, SCI = {sci_locarna:.4f}")

print("cell done")
# Out:
# Loading reference alignment...
#
# --- Clustal W Alignment ---
# Reference alignment length: 106
# Test alignment length: 106
# Common sequences: 14
# Correct pairs: 6238
# Total pairs: 7136
# SPS for Clustal W: 0.8742
#
# --- LocARNA Alignment ---
# Reference alignment length: 106
# Test alignment length: 106
# Common sequences: 14
# Correct pairs: 6274
# Total pairs: 7136
# SPS for LocARNA: 0.8792
# RESULTS
# Clustal W: SPS = 0.8742, SCI = 0.8195
# LocARNA:   SPS = 0.8792, SCI = 0.8195
# cell done
# 14 sequences; length of alignment 106.

# %%
#Building the covariance models
print("----------------------------------------------------")
print("---------------Build Covariance Models--------------")
print("----------------------------------------------------")
#Infernal requires Stockholm format with a consensus structure annotation
#locarna already provides this format, but for clustalw, we need to create it.

# Clustal W alignment with consensus structure
def create_stockholm_with_structure(alignment_dict, structure, output_file):
    with open(output_file, "w") as f:
        f.write("# STOCKHOLM 1.0\n")
        f.write(f"#=GF SQ {len(alignment_dict)}\n")
        
        # Write sequences
        for seq_id, seq in alignment_dict.items():
            f.write(f"{seq_id:<30} {seq}\n")
        
        # Write consensus structure
        f.write(f"#=GC SS_cons{' '*19} {structure}\n")
        f.write("//\n")

# Create Stockholm file for Clustal W alignment
#the consensus structure was directly copied from the RNAalifold output above
consensus_structure = "..........((((.((((..(((((((((..((((((((.......................))))))))...)))))))))..)))).))))............"
create_stockholm_with_structure(clustalw, consensus_structure, "RF00254_clustalw.stk")

# LocARNA already has Stockholm format with structure, so just copy it
# !wsl cp RF00254_seed_ungapped.out/results/result.stk RF00254_locarna.stk

print("cell done")
# Out:
# ----------------------------------------------------
# ---------------Build Covariance Models--------------
# ----------------------------------------------------
# cell done

# %%
# Build CM from Clustal W alignment
# !wsl cmbuild RF00254_clustalw.cm RF00254_clustalw.stk

# Build CM from LocARNA alignment
# !wsl cmbuild RF00254_locarna.cm RF00254_locarna.stk

print("cell done")
# Out:
# # cmbuild :: covariance model construction from multiple sequence alignments
# # INFERNAL 1.1.5 (Sep 2023)
# # Copyright (C) 2023 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # CM file:                                            RF00254_clustalw.cm
# # alignment file:                                     RF00254_clustalw.stk
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #                                                                      rel entropy
# #                                                                      -----------
# # idx    name                     nseq eff_nseq   alen  clen  bps bifs    CM   HMM description
# # ------ -------------------- -------- -------- ------ ----- ---- ---- ----- ----- -----------
#        1 RF00254_clustalw           14     2.29    106    81   24    0 0.700 0.489
# #
# # CPU time: 0.11u 0.01s 00:00:00.12 Elapsed: 00:00:00.16
# # cmbuild :: covariance model construction from multiple sequence alignments
# # INFERNAL 1.1.5 (Sep 2023)
# # Copyright (C) 2023 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # CM file:                                            RF00254_locarna.cm
# # alignment file:                                     RF00254_locarna.stk
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #                                                                      rel entropy
# #                                                                      -----------
# # idx    name                     nseq eff_nseq   alen  clen  bps bifs    CM   HMM description
# # ------ -------------------- -------- -------- ------ ----- ---- ---- ----- ----- -----------
#        1 RF00254_locarna            14     2.27    106    82   24    0 0.691 0.483
# #
# # CPU time: 0.13u 0.00s 00:00:00.13 Elapsed: 00:00:00.14
# cell done

# %%
#Prepare test sequences:
# Load the full alignment, ie all known sequences belonging to this family
full_aln = read_stockholm_alignment("RF00254_full_alignment.sto")

print(f"Full alignment: {len(full_aln)} sequences")
print(f"Seed alignment: {len(reference)} sequences")

#we only want the sequences that were not used in the seed. -> they should be independent
seed_ids = set(reference.keys())
full_ids = set(full_aln.keys())
independent_ids = full_ids - seed_ids

print(f"independent_ids: {len(independent_ids)}")

# Write independent sequences to fasta file
with open("RF00254_independent.fa", "w") as f:
    for seq_id in independent_ids:
        seq = full_aln[seq_id].replace("-", "")  # Remove gaps
        seq = seq.replace(".", "")  # Remove gaps
        f.write(f">{seq_id}\n{seq}\n")

print("Created RF00254_independent.fa")

print("cell done")
# Out:
# Full alignment: 4719 sequences
# Seed alignment: 14 sequences
# independent_ids: 4705
# Created RF00254_independent.fa
# cell done

# %%
#run cmcalibrate, a cm file must be calibrated before it can be used with cmsearch
# !wsl cmcalibrate RF00254_clustalw.cm
# !wsl cmcalibrate RF00254_locarna.cm

print("cell done")
# Out:
# # cmcalibrate :: fit exponential tails for CM E-values
# # INFERNAL 1.1.5 (Sep 2023)
# # Copyright (C) 2023 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # CM file:                                     RF00254_clustalw.cm
# # number of worker threads:                    4
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #
# # Calibrating CM(s):
# #
# #                        predicted                                                   actual
# #                       running time              percent complete                running time
# # model name            (hr:min:sec)  [........25........50........75..........]  (hr:min:sec)
# # --------------------  ------------  ------------------------------------------  ------------
#   RF00254_clustalw          00:03:30  [========================================]      00:10:43
# #
# # Calibration summary statistics:
# #
# #                           exponential tail fit mu        exponential tail fit lambda         total number of hits
# #                       -------------------------------  -------------------------------  -------------------------------
# # model name            glc cyk glc ins loc cyk loc ins  glc cyk glc ins loc cyk loc ins  glc cyk glc ins loc cyk loc ins
# # --------------------  ------- ------- ------- -------  ------- ------- ------- -------  ------- ------- ------- -------
#   RF00254_clustalw        -0.80    2.81    3.18    4.61    0.487   0.534   0.703   0.709    80981   63208  216877  186694
# #
# # CPU time: 2283.72u 70.46s 00:39:14.17 Elapsed: 00:10:43.59
# [ok]
# # cmcalibrate :: fit exponential tails for CM E-values
# # INFERNAL 1.1.5 (Sep 2023)
# # Copyright (C) 2023 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # CM file:                                     RF00254_locarna.cm
# # number of worker threads:                    4
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# #
# # Calibrating CM(s):
# #
# #                        predicted                                                   actual
# #                       running time              percent complete                running time
# # model name            (hr:min:sec)  [........25........50........75..........]  (hr:min:sec)
# # --------------------  ------------  ------------------------------------------  ------------
#   RF00254_locarna           00:05:16  [========================================]      00:08:46
# #
# # Calibration summary statistics:
# #
# #                           exponential tail fit mu        exponential tail fit lambda         total number of hits
# #                       -------------------------------  -------------------------------  -------------------------------
# # model name            glc cyk glc ins loc cyk loc ins  glc cyk glc ins loc cyk loc ins  glc cyk glc ins loc cyk loc ins
# # --------------------  ------- ------- ------- -------  ------- ------- ------- -------  ------- ------- ------- -------
#   RF00254_locarna         -0.91    2.87    3.13    4.58    0.528   0.553   0.706   0.708    80282   62698  222084  190068
# #
# # CPU time: 2002.26u 27.09s 00:33:49.35 Elapsed: 00:08:46.41
# [ok]
# cell done

# %%
#run infernals cmsearch (it searches sequences and tries to find matches to the covariance model)
# !wsl cmsearch RF00254_clustalw.cm RF00254_independent.fa > RF00254_clustalw_search.out
# !wsl cmsearch RF00254_locarna.cm RF00254_independent.fa > RF00254_locarna_search.out

print("cell done")

# %%
# Extract scores from both searches
clustalw_scores = extract_bit_scores("RF00254_clustalw_search.out")
locarna_scores = extract_bit_scores("RF00254_locarna_search.out")

print("RESULTS\n")

print(f"Clustal W CM: {len(clustalw_scores)} hits")
if clustalw_scores:
    print(f"  Mean bit score: {sum(clustalw_scores)/len(clustalw_scores):.2f}")
    print(f"  Max bit score: {max(clustalw_scores):.2f}")
    print(f"  Min bit score: {min(clustalw_scores):.2f}")
    significant_hits = [s for s in clustalw_scores if s > 50]
    print(f"  Significant hits (>50 bits): {len(significant_hits)}")

print(f"\nLocARNA CM: {len(locarna_scores)} hits")
if locarna_scores:
    print(f"  Mean bit score: {sum(locarna_scores)/len(locarna_scores):.2f}")
    print(f"  Max bit score: {max(locarna_scores):.2f}")
    print(f"  Min bit score: {min(locarna_scores):.2f}")
    significant_hits = [s for s in locarna_scores if s > 50]
    print(f"  Significant hits (>50 bits): {len(significant_hits)}")

print("cell done")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Extract scores from both searches
# ----> 2 clustalw_scores = extract_bit_scores("RF00254_clustalw_search.out")
#       3 locarna_scores = extract_bit_scores("RF00254_locarna_search.out")
#       5 print("RESULTS\n")
#
# Cell In[6], line 165, in extract_bit_scores(filename)
#     162 """Extract bit scores from cmsearch output"""
#     163 bit_scores = []
# --> 165 with open(filename, "r") as f:
#     166     for line in f:
#     167         line_stripped = line.strip()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'RF00254_clustalw_search.out'
