# %% [markdown]
# # Install / Setup

# %%
# load the required python components
import sys
import os
# load the Python Image Library (PIL)
from PIL import Image
import RNA
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# define some python helper functions to make working more convenient
#
# concat multiple images of different size
def get_concat_h_blank(im1, im2, color=(255, 255, 255)):
    dst = Image.new('RGB', (im1.width + im2.width, max(im1.height, im2.height)), color)
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

def get_concat_h_multi_blank(im_list):
    _im = im_list.pop(0)
    for im in im_list:
        _im = get_concat_h_blank(_im, im)
    return _im
# use as shown
# img3 = get_concat_h_multi_blank([img1, img2])
# img3

print('Installed Vienna RNA Package v' + RNA.__version__)
# Out:
# Installed Vienna RNA Package v2.7.0

# %% [markdown]
# # Select RNA Families

# %% [markdown]
# # Obtain Data

# %%
#adapted from example project

# Download seed alignment in fasta
# !wsl wget https://rfam.org/family/RF01988/alignment/fasta -O RF01988_seed.fa
# Download seed alignment without gap (ungapped)
# !wsl wget https://rfam.org/family/RF01988/alignment/fastau -O RF01988_seed_ungapped.fa
# Download covariance model
# !wsl wget https://rfam.org/family/RF01988/cm -O RF01988_rfam.cm
# Download and extract all sequences
# !wsl wget https://ftp.ebi.ac.uk/pub/databases/Rfam/15.1/fasta_files/RF01988.fa.gz
# !wsl gunzip RF01988.fa.gz
# Out:
# --2026-01-29 11:13:04--  https://rfam.org/family/RF01988/alignment/fasta
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330 [text/plain]
# Saving to: â€˜RF01988_seed.faâ€™
#
#      0K                                                       100% 67.0M=0s
#
# 2026-01-29 11:13:04 (67.0 MB/s) - â€˜RF01988_seed.faâ€™ saved [330/330]
#
# --2026-01-29 11:13:05--  https://rfam.org/family/RF01988/alignment/fastau
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330 [text/plain]
# Saving to: â€˜RF01988_seed_ungapped.faâ€™
#
#      0K                                                       100% 63.2M=0s
#
# 2026-01-29 11:13:05 (63.2 MB/s) - â€˜RF01988_seed_ungapped.faâ€™ saved [330/330]
#
# --2026-01-29 11:13:05--  https://rfam.org/family/RF01988/cm
# Resolving rfam.org (rfam.org)... 193.62.193.83
# Connecting to rfam.org (rfam.org)|193.62.193.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37874 (37K) [text/plain]
# Saving to: â€˜RF01988_rfam.cmâ€™
#
#      0K .......... .......... .......... ......               100%  675K=0.05s
#
# 2026-01-29 11:13:06 (675 KB/s) - â€˜RF01988_rfam.cmâ€™ saved [37874/37874]
#
# --2026-01-29 11:13:06--  https://ftp.ebi.ac.uk/pub/databases/Rfam/15.1/fasta_files/RF01988.fa.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2837 (2.8K) [application/x-gzip]
# Saving to: â€˜RF01988.fa.gzâ€™
#
#      0K ..                                                    100%  205M=0s
#
# 2026-01-29 11:13:06 (205 MB/s) - â€˜RF01988.fa.gzâ€™ saved [2837/2837]

# %%
#CHECK IF VIENNA RNA works

# Consensus structure prediction using RNAalifold
# Enabling option --sci returns sci value
# !wsl RNAalifold --sci --mis --cfactor=0.6 --nfactor=0.5 --aln RF01988_seed.fa
# Out:
# GYGUCUGACACGGCCCWUCGGUUGCAGGUCUGCACCAWUCGGUCGGUAAYGGCGC
# (((((..((.(((((.((.(((.(((....)))))).)).)))))))...))))) (-17.26 = -17.30 +   0.04) [sci = 0.8309]
# 4 sequences; length of alignment 55.

# %%
#CHECK IF INFERNAL WORKS

# Compute Infernal bit scores using cmsearch
# The tool computes for each sequence in RF01185.fa using covariance model RF01185_rfam.cm
# Option --tblout stores the output table including bit score in RF01185_rfam.score
# !wsl cmsearch --tblout RF01988_rfam.score RF01988_rfam.cm RF01988.fa
# Out:
# # cmsearch :: search CM(s) against a sequence database
# # INFERNAL 1.1.5 (Sep 2023)
# # Copyright (C) 2023 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query CM file:                         RF01988_rfam.cm
# # target sequence database:              RF01988.fa
# # tabular output of hits:                RF01988_rfam.score
# # number of worker threads:              4
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       SECIS_2  [CLEN=55]
# Accession:   RF01988
# Description: Selenocysteine insertion sequence 2
# Hit scores:
#  rank     E-value  score  bias  sequence                           start    end   mdl trunc   gc  description
#  ----   --------- ------ -----  --------------------------------- ------ ------   --- ----- ----  -----------
#   (1) !   1.9e-22   87.6   0.0  AE006468.2/4527101-4527047             1     55 +  cm    no 0.65  Salmonella enterica subsp. enterica serovar
#   (2) !   1.9e-22   87.6   0.0  CP000880.1/3294921-3294975             1     55 +  cm    no 0.65  Salmonella enterica subsp. arizonae serovar
#   (3) !   1.9e-22   87.6   0.0  JMPI01000006.1/51809-51755             1     55 +  cm    no 0.65  Buttiauxella agrestis ATCC 33320 GBAG.assemb
#   (4) !   1.9e-22   87.6   0.0  KK036986.1/686865-686811               1     55 +  cm    no 0.65  Klebsiella michiganensis strain MGH 27 adjbQ
#   (5) !   1.9e-22   87.6   0.0  LS483466.1/4140447-4140501             1     55 +  cm    no 0.65  Salmonella enterica subsp. arizonae strain N
#   (6) !   2.6e-22   87.1   0.0  U00096.2/4296977-4296923               1     55 +  cm    no 0.62  -
#   (7) !   2.6e-22   87.1   0.0  AE005674.2/4308979-4308925             1     55 +  cm    no 0.62  Shigella flexneri 2a str. 301, complete geno
#   (8) !   2.6e-22   87.1   0.0  AE014075.1/4858113-4858059             1     55 +  cm    no 0.62  Escherichia coli CFT073, complete genome
#   (9) !   2.6e-22   87.1   0.0  BA000007.3/5151766-5151712             1     55 +  cm    no 0.62  Escherichia coli O157:H7 str. Sakai DNA, com
#  (10) !   2.6e-22   87.1   0.0  CABFKN010018469.1/1731-1785            1     55 +  cm    no 0.62  Panagrolaimus superbus genome assembly, cont
#  (11) !   2.6e-22   87.1   0.0  CP000038.1/4524386-4524332             1     55 +  cm    no 0.62  Shigella sonnei Ss046, complete genome
#  (12) !   2.6e-22   87.1   0.0  CP000468.1/4645619-4645565             1     55 +  cm    no 0.62  Escherichia coli APEC O1, complete genome
#  (13) !   2.6e-22   87.1   0.0  CP000800.1/4637472-4637418             1     55 +  cm    no 0.62  Escherichia coli E24377A, complete genome
#  (14) !   2.6e-22   87.1   0.0  CP000802.1/4330156-4330102             1     55 +  cm    no 0.62  Escherichia coli HS, complete genome
#  (15) !   2.6e-22   87.1   0.0  CP001665.1/4136332-4136386             1     55 +  cm    no 0.62  Escherichia coli 'BL21-Gold(DE3)pLysS AG', c
#  (16) !   2.6e-22   87.1   0.0  CP001855.1/4368436-4368382             1     55 +  cm    no 0.62  Escherichia coli O83:H1 str. NRG 857C, compl
#  (17) !   2.6e-22   87.1   0.0  CU928145.2/4690274-4690220             1     55 +  cm    no 0.62  Escherichia coli 55989 chromosome, complete
#  (18) !   2.6e-22   87.1   0.0  CU928161.2/4560147-4560093             1     55 +  cm    no 0.62  Escherichia coli S88 chromosome, complete ge
#  (19) !   2.6e-22   87.1   0.0  FM180568.1/4649358-4649304             1     55 +  cm    no 0.62  Escherichia coli 0127:H6 E2348/69 complete g
#  (20) !   2.6e-22   87.1   0.0  U00096.3/4298954-4298900               1     55 +  cm    no 0.62  Escherichia coli str. K-12 substr. MG1655, c
#  (21) !   3.8e-22   86.5   0.0  ANFO01000248.1/8044-8098               1     55 +  cm    no 0.65  Beauveria bassiana D1-5 contig00268, whole g
#  (22) !   3.8e-22   86.5   0.0  CP002272.1/4399564-4399618             1     55 +  cm    no 0.65  Enterobacter lignolyticus SCF1, complete gen
#  (23) !   4.4e-22   86.3   0.0  CU928158.2/4397661-4397715             1     55 +  cm    no 0.67  -
#  (24) !   4.4e-22   86.3   0.0  AAAA02040203.1/1187-1133               1     55 +  cm    no 0.67  Oryza sativa Indica Group cultivar 93-11 Ctg
#  (25) !   4.4e-22   86.3   0.0  AWUE01003100.1/915-861                 1     55 +  cm    no 0.67  Corchorus olitorius cultivar O-4 contig03105
#  (26) !   4.4e-22   86.3   0.0  CP000653.1/331522-331468               1     55 +  cm    no 0.67  Enterobacter sp. 638 chromosome, complete ge
#  (27) !   4.4e-22   86.3   0.0  CP000822.1/3531776-3531830             1     55 +  cm    no 0.67  Citrobacter koseri ATCC BAA-895, complete ge
#  (28) !   4.4e-22   86.3   0.0  FN543502.1/3662130-3662076             1     55 +  cm    no 0.67  Citrobacter rodentium ICC168, complete genom
#  (29) !   4.4e-22   86.3   0.0  LGIT01000001.1/27364-27418             1     55 +  cm    no 0.67  Klebsiella sp. RIT-PI-d NODE_5_length_106553
#  (30) !   4.4e-22   86.3   0.0  WAAG01059158.1/75520-75466             1     55 +  cm    no 0.67  Tichodroma muraria voucher UWBM:61504 isolat
#  (31) !   4.4e-22   86.3   0.0  WBMX01030139.1/326-380                 1     55 +  cm    no 0.67  Corythaeola cristata voucher FMNH:AVES:35794
#  (32) !   4.4e-22   86.3   0.0  WJYB01000004.1/87846-87792             1     55 +  cm    no 0.67  Enterobacteriaceae bacterium RIT714 4, whole
#  (33) !     6e-22   85.8   0.0  CP003938.1/4373133-4373187             1     55 +  cm    no 0.64  Enterobacteriaceae bacterium strain FGI 57,
#  (34) !     6e-22   85.8   0.0  CP009451.1/2288436-2288490             1     55 +  cm    no 0.64  Cedecea neteri strain SSMD04, complete genom
#  (35) !   6.8e-22   85.6   0.0  BAFF01000006.1/164640-164694           1     55 +  cm    no 0.65  Atlantibacter hermannii NBRC 105704 NBRC 105
#  (36) !   7.5e-22   85.4   0.0  CAADJD010000006.1/32525-32471          1     55 +  cm    no 0.65  Kluyvera cryocrescens strain NCTC12993 genom
#  (37) !   7.5e-22   85.4   0.0  CP022114.1/2435494-2435440             1     55 +  cm    no 0.65  Kluyvera genomosp. 3 strain YDC799 chromosom
#  (38) !   7.5e-22   85.4   0.0  JABXSS010000001.1/3839960-3840014      1     55 +  cm    no 0.65  Citrobacter freundii strain RHB34-C11 RHB34-
#  (39) !   7.5e-22   85.4   0.0  LDZF01000006.1/251060-251114           1     55 +  cm    no 0.65  Pluralibacter gergoviae strain JS81F13 conti
#  (40) !   1.2e-21   84.7   0.0  CP001560.1/3751479-3751533             1     55 +  cm    no 0.64  Shimwellia blattae DSM 4481 = NBRC 105725, c
#  (41) !   1.2e-21   84.7   0.0  CP022114.1/4580111-4580165             1     55 +  cm    no 0.64  Kluyvera genomosp. 3 strain YDC799 chromosom
#  (42) !   1.5e-21   84.3   0.0  JJMI01000005.1/180650-180704           1     55 +  cm    no 0.65  Mangrovibacter sp. MFB070 Contig-005, whole
#  (43) !   1.5e-21   84.3   0.0  JNGI01000012.1/74408-74354             1     55 +  cm    no 0.65  Trabulsiella odontotermitis strain 12 SAMPLE
#  (44) !   1.7e-21   84.1   0.0  CP003200.1/364443-364389               1     55 +  cm    no 0.67  Klebsiella pneumoniae subsp. pneumoniae HS11
#  (45) !   1.7e-21   84.1   0.0  CP009451.1/297310-297364               1     55 +  cm    no 0.67  Cedecea neteri strain SSMD04, complete genom
#  (46) !   1.7e-21   84.1   0.0  CP040428.1/2721610-2721556             1     55 +  cm    no 0.67  Jejubacter calystegiae strain KSNA2 chromoso
#  (47) !   1.7e-21   84.1   0.0  FN543502.1/3567947-3567893             1     55 +  cm    no 0.67  Citrobacter rodentium ICC168, complete genom
#  (48) !   1.7e-21   84.1   0.0  JAEPBH010000041.1/23600-23654          1     55 +  cm    no 0.67  Tenebrionibacter intestinalis strain BIT-L3
#  (49) !   1.7e-21   84.1   0.0  LDZF01000002.1/76265-76319             1     55 +  cm    no 0.67  Pluralibacter gergoviae strain JS81F13 conti
#  (50) !   1.7e-21   84.1   0.0  UGLZ01000005.1/1035764-1035710         1     55 +  cm    no 0.67  Klebsiella pneumoniae subsp. ozaenae strain
#  (51) !   1.7e-21   84.1   0.0  VCHQ01000002.1/23726-23672             1     55 +  cm    no 0.67  Klebsiella indica strain TOUT106 salmonela_m
#  (52) !   9.3e-21   81.4   0.0  CP009706.1/998970-998916               1     55 +  cm    no 0.67  Hafnia alvei FB1, complete genome
#  (53) !   1.4e-20   80.7   0.0  QRAP01000018.1/1950-1896               1     55 +  cm    no 0.65  Enterobacillus tribolii strain DSM 103736 Ga
#  (54) !   1.7e-20   80.4   0.0  BBMZ01000003.1/61444-61498             1     55 +  cm    no 0.67  Pseudescherichia vulneris NBRC 102420 DNA, c
#  (55) !     2e-20   80.2   0.0  CP000783.1/1992402-1992348             1     55 +  cm    no 0.69  Cronobacter sakazakii ATCC BAA-894, complete
#  (56) !   2.7e-20   79.7   0.0  CP019445.1/822509-822563               1     55 +  cm    no 0.65  Kosakonia cowanii JCM 10956 = DSM 18146 stra
#  (57) !   4.1e-20   79.1   0.0  ABXW01000042.1/36779-36725             1     55 +  cm    no 0.64  -
#  (58) !   4.1e-20   79.1   0.0  CM001773.1/3482362-3482308             1     55 +  cm    no 0.64  Providencia sneebia DSM 19967 chromosome, wh
#  (59) !   4.1e-20   79.1   0.0  LXEW01000046.1/36454-36400             1     55 +  cm    no 0.64  Providencia heimbachae ATCC 35613 Sequence00
#  (60) !   4.7e-20   78.8   0.0  AYKS02000053.1/80785-80731             1     55 +  cm    no 0.65  Serratia sp. DD3 SRDD_contig000053, whole ge
#  (61) !   4.7e-20   78.8   0.0  CP004345.1/3693837-3693783             1     55 +  cm    no 0.65  Morganella morganii subsp. morganii KT, comp
#  (62) !   5.8e-20   78.5   0.0  BAAW01013798.1/777-831                 1     55 +  cm    no 0.73  -
#  (63) !   9.5e-20   77.7   0.0  KK036986.1/2857747-2857693             1     55 +  cm    no 0.69  Klebsiella michiganensis strain MGH 27 adjbQ
#  (64) !   1.1e-19   77.5   0.0  CP011254.1/4155074-4155020             1     55 +  cm    no 0.69  Serratia fonticola strain DSM 4576, complete
#  (65) !   1.6e-19   76.9   0.0  WBMX01016699.1/8041-8095               1     55 +  cm    no 0.67  Corythaeola cristata voucher FMNH:AVES:35794
#  (66) !   5.1e-19   75.0   0.0  UFXZ01000001.1/657134-657080           1     55 +  cm    no 0.69  Edwardsiella hoshinae strain NCTC12121 genom
#  (67) !   6.3e-19   74.7   0.0  CP038613.1/2783382-2783328             1     55 +  cm    no 0.64  Arsenophonus nasoniae strain FIN chromosome,
#  (68) !   7.3e-19   74.5   0.0  LXEN01000098.1/17882-17936             1     55 +  cm    no 0.62  Proteus myxofaciens ATCC 19692 Sequence00098
#  (69) !   9.6e-19   74.0   0.0  JAEPBH010000011.1/30550-30604          1     55 +  cm    no 0.69  Tenebrionibacter intestinalis strain BIT-L3
#  (70) !   1.6e-18   73.3   0.0  LS483470.1/3577595-3577649             1     55 +  cm    no 0.71  Leminorella richardii strain NCTC12151 genom
#  ------ inclusion threshold ------
#  (71) ?     0.032   13.4   0.0  AE006468.2/4527101-4527047            55      1 -  cm    no 0.65  Salmonella enterica subsp. enterica serovar
#  (72) ?     0.032   13.4   0.0  CP000880.1/3294921-3294975            55      1 -  cm    no 0.65  Salmonella enterica subsp. arizonae serovar
#  (73) ?     0.032   13.4   0.0  JMPI01000006.1/51809-51755            55      1 -  cm    no 0.65  Buttiauxella agrestis ATCC 33320 GBAG.assemb
#  (74) ?     0.032   13.4   0.0  KK036986.1/686865-686811              55      1 -  cm    no 0.65  Klebsiella michiganensis strain MGH 27 adjbQ
#  (75) ?     0.032   13.4   0.0  LS483466.1/4140447-4140501            55      1 -  cm    no 0.65  Salmonella enterica subsp. arizonae strain N
#
#
# Hit alignments:
# >> AE006468.2/4527101-4527047  Salmonella enterica subsp. enterica serovar Typhimurium str. LT2, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (1) !   1.9e-22   87.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAA+GGCGC
#   AE006468.2/4527101-4527047  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> CP000880.1/3294921-3294975  Salmonella enterica subsp. arizonae serovar 62:z4,z23:- strain RSK2980 chromosome, comple
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (2) !   1.9e-22   87.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAA+GGCGC
#   CP000880.1/3294921-3294975  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> JMPI01000006.1/51809-51755  Buttiauxella agrestis ATCC 33320 GBAG.assembly.006, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (3) !   1.9e-22   87.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAA+GGCGC
#   JMPI01000006.1/51809-51755  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> KK036986.1/686865-686811  Klebsiella michiganensis strain MGH 27 adjbQ-supercont1.1, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (4) !   1.9e-22   87.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAA+GGCGC
#   KK036986.1/686865-686811  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                               ******************************************************* PP
#
# >> LS483466.1/4140447-4140501  Salmonella enterica subsp. arizonae strain NCTC7307 genome assembly, chromosome: 1
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (5) !   1.9e-22   87.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAA+GGCGC
#   LS483466.1/4140447-4140501  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> U00096.2/4296977-4296923
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (6) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   U00096.2/4296977-4296923  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                               ******************************************************* PP
#
# >> AE005674.2/4308979-4308925  Shigella flexneri 2a str. 301, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (7) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   AE005674.2/4308979-4308925  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> AE014075.1/4858113-4858059  Escherichia coli CFT073, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (8) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   AE014075.1/4858113-4858059  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> BA000007.3/5151766-5151712  Escherichia coli O157:H7 str. Sakai DNA, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#   (9) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   BA000007.3/5151766-5151712  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CABFKN010018469.1/1731-1785  Panagrolaimus superbus genome assembly, contig: PSU_contig_31829, whole genome shotgun s
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (10) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                          NC
#                                  <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                       SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                  G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CABFKN010018469.1/1731-1785  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                  ******************************************************* PP
#
# >> CP000038.1/4524386-4524332  Shigella sonnei Ss046, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (11) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP000038.1/4524386-4524332  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP000468.1/4645619-4645565  Escherichia coli APEC O1, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (12) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP000468.1/4645619-4645565  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP000800.1/4637472-4637418  Escherichia coli E24377A, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (13) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP000800.1/4637472-4637418  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP000802.1/4330156-4330102  Escherichia coli HS, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (14) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP000802.1/4330156-4330102  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP001665.1/4136332-4136386  Escherichia coli 'BL21-Gold(DE3)pLysS AG', complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (15) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP001665.1/4136332-4136386  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP001855.1/4368436-4368382  Escherichia coli O83:H1 str. NRG 857C, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (16) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CP001855.1/4368436-4368382  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CU928145.2/4690274-4690220  Escherichia coli 55989 chromosome, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (17) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CU928145.2/4690274-4690220  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CU928161.2/4560147-4560093  Escherichia coli S88 chromosome, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (18) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   CU928161.2/4560147-4560093  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> FM180568.1/4649358-4649304  Escherichia coli 0127:H6 E2348/69 complete genome, strain E2348/69
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (19) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   FM180568.1/4649358-4649304  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> U00096.3/4298954-4298900  Escherichia coli str. K-12 substr. MG1655, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (20) !   2.6e-22   87.1   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               G:GUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGC:C
#   U00096.3/4298954-4298900  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC 55
#                               ******************************************************* PP
#
# >> ANFO01000248.1/8044-8098  Beauveria bassiana D1-5 contig00268, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (21) !   3.8e-22   86.5   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAAUGGCGC
#   ANFO01000248.1/8044-8098  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAAUGGCGC 55
#                               ******************************************************* PP
#
# >> CP002272.1/4399564-4399618  Enterobacter lignolyticus SCF1, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (22) !   3.8e-22   86.5   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAAUGGCGC
#   CP002272.1/4399564-4399618  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CU928158.2/4397661-4397715
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (23) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   CU928158.2/4397661-4397715  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> AAAA02040203.1/1187-1133  Oryza sativa Indica Group cultivar 93-11 Ctg040203, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (24) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   AAAA02040203.1/1187-1133  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                               ******************************************************* PP
#
# >> AWUE01003100.1/915-861  Corchorus olitorius cultivar O-4 contig03105, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (25) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                     NC
#                             <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                  SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                             GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   AWUE01003100.1/915-861  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                             ******************************************************* PP
#
# >> CP000653.1/331522-331468  Enterobacter sp. 638 chromosome, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (26) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                       NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   CP000653.1/331522-331468  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                               ******************************************************* PP
#
# >> CP000822.1/3531776-3531830  Citrobacter koseri ATCC BAA-895, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (27) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   CP000822.1/3531776-3531830  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> FN543502.1/3662130-3662076  Citrobacter rodentium ICC168, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (28) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   FN543502.1/3662130-3662076  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> LGIT01000001.1/27364-27418  Klebsiella sp. RIT-PI-d NODE_5_length_106553_cov_38.4184_ID_9, whole genome shotgun seque
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (29) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   LGIT01000001.1/27364-27418  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> WAAG01059158.1/75520-75466  Tichodroma muraria voucher UWBM:61504 isolate B10K-DU-012-47 scaffold96706, whole genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (30) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   WAAG01059158.1/75520-75466  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> WBMX01030139.1/326-380  Corythaeola cristata voucher FMNH:AVES:357942 isolate B10K-CU-031-40 scaffold_30512, whole ge
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (31) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                     NC
#                             <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                  SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                             GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   WBMX01030139.1/326-380  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                             ******************************************************* PP
#
# >> WJYB01000004.1/87846-87792  Enterobacteriaceae bacterium RIT714 4, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (32) !   4.4e-22   86.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGCGC
#   WJYB01000004.1/87846-87792  1 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> CP003938.1/4373133-4373187  Enterobacteriaceae bacterium strain FGI 57, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (33) !     6e-22   85.8   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.64
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAAUGGC:C
#   CP003938.1/4373133-4373187  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> CP009451.1/2288436-2288490  Cedecea neteri strain SSMD04, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (34) !     6e-22   85.8   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.64
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAAUGGC:C
#   CP009451.1/2288436-2288490  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> BAFF01000006.1/164640-164694  Atlantibacter hermannii NBRC 105704 NBRC 105704 DNA, contig: EH10570406, whole genome s
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (35) !   6.8e-22   85.6   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                           NC
#                                   <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                        SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                   G:GUCUGACACGGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUCGGUAA+GGC:C
#   BAFF01000006.1/164640-164694  1 GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC 55
#                                   ******************************************************* PP
#
# >> CAADJD010000006.1/32525-32471  Kluyvera cryocrescens strain NCTC12993 genome assembly, contig: ERS473437SCcontig00000
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (36) !   7.5e-22   85.4   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                            NC
#                                    <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                         SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                    GCGUCUGACACGGCCC:UCGGUUGCAGGUCUGCACCAA:CGGUCGGUAA+GGCGC
#   CAADJD010000006.1/32525-32471  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                    ******************************************************* PP
#
# >> CP022114.1/2435494-2435440  Kluyvera genomosp. 3 strain YDC799 chromosome, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (37) !   7.5e-22   85.4   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCC:UCGGUUGCAGGUCUGCACCAA:CGGUCGGUAA+GGCGC
#   CP022114.1/2435494-2435440  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> JABXSS010000001.1/3839960-3840014  Citrobacter freundii strain RHB34-C11 RHB34-C11_1, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (38) !   7.5e-22   85.4   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                                NC
#                                        <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                             SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                        GCGUCUGACACGGCCC:UCGGUUGCAGGUCUGCACCAA:CGGUCGGUAA+GGCGC
#   JABXSS010000001.1/3839960-3840014  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAACGGCGC 55
#                                        ******************************************************* PP
#
# >> LDZF01000006.1/251060-251114  Pluralibacter gergoviae strain JS81F13 contig_6, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (39) !   7.5e-22   85.4   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                           NC
#                                   <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                        SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                   GCGUCUGACACGGCCC:UCGGUUGCAGGUCUGCACCAA:CGGUCGGUAA+GGCGC
# ...
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCC::CG:UUGCAGGUCUGCA:C ::CGGUCGGUAA+GGC:C
#   AYKS02000053.1/80785-80731  1 GUGUCUGACACGGCCCUUCGGUUGCAGGUCUGCAGCGUUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> CP004345.1/3693837-3693783  Morganella morganii subsp. morganii KT, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (61) !   4.7e-20   78.8   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.65
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G:GUCUGACACGGCCC::CG:UUGCAGGUCUGCA:C ::CGGUCGGUAA+GGC:C
#   CP004345.1/3693837-3693783  1 GUGUCUGACACGGCCCUUCGGUUGCAGGUCUGCAGCGUUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> BAAW01013798.1/777-831
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (62) !   5.8e-20   78.5   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.73
#
#                                                                                     NC
#                             <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                  SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                             GCGUCUGACACGG:CCAUCGG:UGC:GGUC:GC:CC AUCG:UCGGU A+GGCGC
#   BAAW01013798.1/777-831  1 GCGUCUGACACGGGCCAUCGGUUGCCGGUCUGCGCCCAUCGGUCGGUGACGGCGC 55
#                             ******************************************************* PP
#
# >> KK036986.1/2857747-2857693  Klebsiella michiganensis strain MGH 27 adjbQ-supercont1.1, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (63) !   9.5e-20   77.7   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.69
#
#                                        v                                      v         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUG CACGGCCC::CGGUUGCAGGUCUGCACCA::CGGUCGG AA+GGCGC
#   KK036986.1/2857747-2857693  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCAGUCGGUCGGCAACGGCGC 55
#                                 ******************************************************* PP
#
# >> CP011254.1/4155074-4155020  Serratia fonticola strain DSM 4576, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (64) !   1.1e-19   77.5   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.69
#
#                                                 v                     v                 NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUGACACGGCCC UCG:UUGCAGGUCUGCA:C A CGGUCGGUAA+GGCGC
#   CP011254.1/4155074-4155020  1 GCGUCUGACACGGCCCCUCGGUUGCAGGUCUGCAGCGAUCGGUCGGUAACGGCGC 55
#                                 ******************************************************* PP
#
# >> WBMX01016699.1/8041-8095  Corythaeola cristata voucher FMNH:AVES:357942 isolate B10K-CU-031-40 scaffold_16780, whole
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (65) !   1.6e-19   76.9   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.67
#
#                                      v                                      v         NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                               GCGUCUG CACGGCCC::CGGUUGCAGGUCUGCACCA::CGGUCGG AAUGGCGC
#   WBMX01016699.1/8041-8095  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCAGUCGGUCGGGAAUGGCGC 55
#                               ******************************************************* PP
#
# >> UFXZ01000001.1/657134-657080  Edwardsiella hoshinae strain NCTC12121 genome assembly, contig: ERS1295689SCcontig00000
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (66) !   5.1e-19   75.0   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.69
#
#                                          v                                      v         NC
#                                   <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                        SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                   GCGUCUG CACGGCCC:UCG:UUGCAGGUCUGCA:C A:CGGUCGG AA+GGCGC
#   UFXZ01000001.1/657134-657080  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCAGCGAUCGGUCGGCAACGGCGC 55
#                                   ******************************************************* PP
#
# >> CP038613.1/2783382-2783328  Arsenophonus nasoniae strain FIN chromosome, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (67) !   6.3e-19   74.7   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.64
#
#                                        v                                      v         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUG CA GGCCCA:CGGUUGCAGGUCUGCACCA:UCGGUC G AAUGGCGC
#   CP038613.1/2783382-2783328  1 GCGUCUGACAUGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGAAAUGGCGC 55
#                                 ******************************************************* PP
#
# >> LXEN01000098.1/17882-17936  Proteus myxofaciens ATCC 19692 Sequence00098, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (68) !   7.3e-19   74.5   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.62
#
#                                                                                         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 G: UCUGACACGGCCC::CG:UUGCAGGUCUGCA:C ::CGGUCGGUAAUGG :C
#   LXEN01000098.1/17882-17936  1 GUGUCUGACACGGCCCUUCGGUUGCAGGUCUGCAGCGUUCGGUCGGUAAUGGUGC 55
#                                 ******************************************************* PP
#
# >> JAEPBH010000011.1/30550-30604  Tenebrionibacter intestinalis strain BIT-L3 Scaffold11, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (69) !   9.6e-19   74.0   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.69
#
#                                           v        v                     v       v         NC
#                                    <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                         SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                    GCGUCUG CACGGCCC :CGGUUGCAGGUCUGCACCA: CGGUCGG AAUGGCGC
#   JAEPBH010000011.1/30550-30604  1 GCGUCUGACACGGCCCCUCGGUUGCAGGUCUGCACCAGUCGGUCGGCAAUGGCGC 55
#                                    ******************************************************* PP
#
# >> LS483470.1/3577595-3577649  Leminorella richardii strain NCTC12151 genome assembly, chromosome: 1
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (70) !   1.6e-18   73.3   0.0  cm        1       55 []           1          55 + [] 1.00    no 0.71
#
#                                        v         v                   v        v         NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGCaCCaauCGGUCGGUAAuGGCgC 55
#                                 GCGUCUG CACGGCCC: CGGUUGCAGGUCUGCACC  :CGGUCGG AA+GGCGC
#   LS483470.1/3577595-3577649  1 GCGUCUGACACGGCCCUUCGGUUGCAGGUCUGCACCGCUCGGUCGGCAACGGCGC 55
#                                 ******************************************************* PP
#
# >> AE006468.2/4527101-4527047  Salmonella enterica subsp. enterica serovar Typhimurium str. LT2, complete genome
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (71) ?     0.032   13.4   0.0  cm        1       55 []          55           1 - [] 0.97    no 0.65
#
#                                    v        v                              v        v    NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>.>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGC.aCCaauCGGUCGGUAAuGGCgC 55
#                                 GCG C     CG CC AU GGU GCAG  CUGC ACC AU GG CG     G CGC
#   AE006468.2/4527101-4527047 55 GCGCCGUUACCGACCGAUUGGU-GCAGACCUGCaACCGAUGGGCCGUGUCAGACGC 1
#                                 *****99999***********7.**********98***********99999***** PP
#
# >> CP000880.1/3294921-3294975  Salmonella enterica subsp. arizonae serovar 62:z4,z23:- strain RSK2980 chromosome, comple
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (72) ?     0.032   13.4   0.0  cm        1       55 []          55           1 - [] 0.97    no 0.65
#
#                                    v        v                              v        v    NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>.>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGC.aCCaauCGGUCGGUAAuGGCgC 55
#                                 GCG C     CG CC AU GGU GCAG  CUGC ACC AU GG CG     G CGC
#   CP000880.1/3294921-3294975 55 GCGCCGUUACCGACCGAUUGGU-GCAGACCUGCaACCGAUGGGCCGUGUCAGACGC 1
#                                 *****99999***********7.**********98***********99999***** PP
#
# >> JMPI01000006.1/51809-51755  Buttiauxella agrestis ATCC 33320 GBAG.assembly.006, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (73) ?     0.032   13.4   0.0  cm        1       55 []          55           1 - [] 0.97    no 0.65
#
#                                    v        v                              v        v    NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>.>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGC.aCCaauCGGUCGGUAAuGGCgC 55
#                                 GCG C     CG CC AU GGU GCAG  CUGC ACC AU GG CG     G CGC
#   JMPI01000006.1/51809-51755 55 GCGCCGUUACCGACCGAUUGGU-GCAGACCUGCaACCGAUGGGCCGUGUCAGACGC 1
#                                 *****99999***********7.**********98***********99999***** PP
#
# >> KK036986.1/686865-686811  Klebsiella michiganensis strain MGH 27 adjbQ-supercont1.1, whole genome shotgun sequence
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (74) ?     0.032   13.4   0.0  cm        1       55 []          55           1 - [] 0.97    no 0.65
#
#                                  v        v                              v        v    NC
#                               <<<<<--<<-<<<<<-<<-<<<-<<<____>>>.>>>->>->>>>>>>--->>>>> CS
#                    SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGC.aCCaauCGGUCGGUAAuGGCgC 55
#                               GCG C     CG CC AU GGU GCAG  CUGC ACC AU GG CG     G CGC
#   KK036986.1/686865-686811 55 GCGCCGUUACCGACCGAUUGGU-GCAGACCUGCaACCGAUGGGCCGUGUCAGACGC 1
#                               *****99999***********7.**********98***********99999***** PP
#
# >> LS483466.1/4140447-4140501  Salmonella enterica subsp. arizonae strain NCTC7307 genome assembly, chromosome: 1
#  rank     E-value  score  bias mdl mdl from   mdl to       seq from      seq to       acc trunc   gc
#  ----   --------- ------ ----- --- -------- --------    ----------- -----------      ---- ----- ----
#  (75) ?     0.032   13.4   0.0  cm        1       55 []          55           1 - [] 0.97    no 0.65
#
#                                    v        v                              v        v    NC
#                                 <<<<<--<<-<<<<<-<<-<<<-<<<____>>>.>>>->>->>>>>>>--->>>>> CS
#                      SECIS_2  1 GcGUCUGACACGGCCCauCGGuUGCaGGUCuGC.aCCaauCGGUCGGUAAuGGCgC 55
#                                 GCG C     CG CC AU GGU GCAG  CUGC ACC AU GG CG     G CGC
#   LS483466.1/4140447-4140501 55 GCGCCGUUACCGACCGAUUGGU-GCAGACCUGCaACCGAUGGGCCGUGUCAGACGC 1
#                                 *****99999***********7.**********98***********99999***** PP
#
#
#
# Internal CM pipeline statistics summary:
# ----------------------------------------
# Query model(s):                                                  1  (55 consensus positions)
# Target sequences:                                               70  (7700 residues searched)
# Target sequences re-searched for truncated hits:                70  (23100 residues re-searched)
# Windows   passing  local HMM SSV           filter:             541  (0.9661); expected (0.35)
# Windows   passing  local HMM Viterbi       filter:                  (off)
# Windows   passing  local HMM Viterbi  bias filter:                  (off)
# Windows   passing  local HMM Forward       filter:             541  (0.9661); expected (0.02)
# Windows   passing  local HMM Forward  bias filter:             536  (0.9571); expected (0.02)
# Windows   passing glocal HMM Forward       filter:             413  (0.7375); expected (0.02)
# Windows   passing glocal HMM Forward  bias filter:             413  (0.7375); expected (0.02)
# Envelopes passing glocal HMM envelope defn filter:             413  (0.6618); expected (0.02)
# Envelopes passing  local CM  CYK           filter:             285  (0.5089); expected (0.0001)
# Total CM hits reported:                                         75  (0.1339); includes 0 truncated hit(s)
#
# # CPU time: 0.67u 0.01s 00:00:00.68 Elapsed: 00:00:00.69
# //
# [ok]

# %%
#CHECK IF locarna works

# Here we run mlocarna for multiple sequence alignment on ungapped seed sequences and
# store the resulting alignment into stockholm format including the consensus structure 
# !wsl mlocarna --stockholm --consensus-structure alifold RF01988_seed_ungapped.fa
# Out:
# mLocARNA --- multiple Local (and global) Alignment of RNA --- LocARNA 2.0.1
#
#
# U00096.2/4296977-4296923   GUGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAAUCGGUCGGUAAUGGCGC
# CU928158.2/4397661-4397715 GCGUCUGACACGGCCCAUCGGUUGCAGGUCUGCACCAGUCGGUCGGUAACGGCGC
# ABXW01000042.1/36779-36725 GUGUCUGACACGGCCCUUCGGUUGCAGGUCUGCAGCGUUCGGUCGGUAAUGGCGC
# BAAW01013798.1/777-831     GCGUCUGACACGGGCCAUCGGUUGCCGGUCUGCGCCCAUCGGUCGGUGACGGCGC
#
# alifold                    (((((..((.(((((.((.(((.(((....)))))).)).)))))))...))))) (-27.19 = -17.30 +  -9.89)
# Results written to target directory /mnt/c/Users/seppo/Bioinformatik_Praktikum_WS25/RF01988_seed_ungapped.out.

# %% [markdown]
# # Prepare Sequence Sets

# %% [markdown]
# # Generate Alignments

# %% [markdown]
# # Predict Consensus Secondary Structures

# %% [markdown]
# # Evaluate Alignments Quantitatively

# %% [markdown]
# # Manual Error Detection (Professor’s Key Point)

# %% [markdown]
# # Correct Alignment Errors

# %% [markdown]
# # Structure-Guided Re-alignment

# %% [markdown]
# # Build Covariance Models (CMs)

# %% [markdown]
# # Evaluate Models Using Bit Scores

# %% [markdown]
# # Interpret and Compare Results
